# %% [markdown]
# # Radar de Candles - 27/01/2021
# Código base disponível [aqui](https://github.com/thiagocrd/radar-candles-graficos/blob/main/charts-code.ipynb)
#
# *devido a alguma inconsistência com a fonte de dados (Yahoo Finance) com as cotações do dia 26/01, alguns gráficos como COGN3, CYRE3, EGIE3, HAPV3 e GOAU4 não refletem o padrão indicado. Devido a esse contratempo, recomendo que consulte uma plataforma como o TradingView para gráficos mais precisos.

# %%
# Out:
# ## Harami de fundo
# ##
# ## Piercing pattern
# ##
# ## Engolfo de alta
# ##
# ## Engolfo de baixa
# ##
# ## Martelo
# ##
# ## Evening star
