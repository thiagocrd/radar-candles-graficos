# %% [markdown]
# # Radar de Candles - 26/01/2021
# Código base disponível [aqui](https://github.com/thiagocrd/radar-candles-graficos/blob/main/charts-code.ipynb)

# %%
# Out:
# ## Harami de fundo
# ##
# ## Martelo invertido
# ##
# ## Shooting star
# ##
# ## Engolfo de baixa
# ##
# ## Morning star (algumas + ou -)
